# %% [markdown]
#     DATA UNDERSTANDING
#
# The data  used for this project was from the aviation department.it containedinformation on fatalities incurred whether fatal or non fatal for different states in the US and other countries.i chose to use the data for mexico.the data contained the following:
# *sum of number by engine type
# *sum of totalminor injuries by purpose of flight
# *count of event by country.
# *broad phase of th flight
# *total uninjured
# *aircraft damage.
# *weather condition.
# *purpose of flight
# *total minor injuries
# *total serious injuries
# *report status

# %%
#STEP 2:IMPORTTING THE NECCESSARY LIBRARIES

# %%
#import the neccessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Correct file path using raw string or escaped backslashes
file_path = r"C:\Users\ADMIN\Desktop\end of phase tech\AviationData.csv"

# Read the CSV file with latin-1 encoding into a DataFrame
df = pd.read_csv(file_path, encoding='latin-1')

# Print the first few rows of the DataFrame
print(df.head())
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country   Latitude  Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States        NaN        NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN        NaN          NaN
# 2    Saltville, VA  United States  36.922223 -81.878056          NaN
# 3       EUREKA, CA  United States        NaN        NaN          NaN
# 4       Canton, OH  United States        NaN        NaN          NaN
#
#   Airport.Name  ... Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# 0          NaN  ...          Personal         NaN                  2.0
# ...

# %%
#FILTERING THE DATA TO USE FOR THE PROJECT

# %% [markdown]
# the data is  voluminous ad for this project i chose to work with Mexico data

# %%
#2.1extracting mexico data from aviationData,called df1

# %%
#loading Mexico data df1
df1 = df[df['Country'] == 'Mexico']
print(df1.head())
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 11207  20001214X35906           Incident      FTW85IA168  1985-03-29
# 16837  20001213X30244           Accident      FTW87RA066  1987-02-14
# 16866  20001213X30245           Accident      FTW87WA070  1987-02-20
# 17578  20001213X30977           Accident      LAX87WA216  1987-05-23
# 19110  20001213X32507           Incident      DCA88RA002  1987-11-07
#
#                       Location Country Latitude Longitude Airport.Code  \
# 11207      MEXICO CITY, Mexico  Mexico      NaN       NaN          DFW
# 16837          DURANGO, Mexico  Mexico      NaN       NaN          NaN
# 16866  LA UNION MORALE, Mexico  Mexico      NaN       NaN          NaN
# 17578         MEXICALI, MEXICO  Mexico      NaN       NaN          NaN
# 19110          TIJUANA, Mexico  Mexico      NaN       NaN          NaN
#
#       Airport.Name  ... Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# ...

# %%
#checking how the df1 looks like
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 358 entries, 11207 to 88603
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                358 non-null    object
#  1   Investigation.Type      358 non-null    object
#  2   Accident.Number         358 non-null    object
#  3   Event.Date              358 non-null    object
#  4   Location                358 non-null    object
#  5   Country                 358 non-null    object
#  6   Latitude                96 non-null     object
#  7   Longitude               96 non-null     object
#  8   Airport.Code            39 non-null     object
#  9   Airport.Name            38 non-null     object
#  10  Injury.Severity         309 non-null    object
#  11  Aircraft.damage         301 non-null    object
#  12  Aircraft.Category       245 non-null    object
#  13  Registration.Number     294 non-null    object
# ...

# %%
#checking the last 5 columns
df1.tail()
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 87880  20220621105288           Incident      ENG22WA031  2022-05-30
# 87909  20220620105276           Incident      ENG22WA030  2022-06-04
# 88104  20220816105750           Accident      GAA22WA249  2022-07-06
# 88136  20220718105505           Accident      GAA22WA227  2022-07-12
# 88603  20221005106062           Accident      GAA22WA294  2022-09-30
#
#            Location Country Latitude Longitude Airport.Code  \
# 87880     Apodaca,   Mexico      NaN       NaN          NaN
# 87909     Tijuana,   Mexico  323227N  1165812E         MMTJ
# 88104  Tamaulipas,   Mexico      NaN       NaN          NaN
# 88136   Queretaro,   Mexico      NaN       NaN          NaN
# 88603      Toluca,   Mexico      NaN       NaN          NaN
#
#                         Airport.Name  ... Purpose.of.flight   Air.carrier  \
# 87880                            NaN  ...               NaN  Viva Aerobus
# ...

# %%
#checking how unique df1 is
df1['Country'].unique()
# Out:
# array(['Mexico'], dtype=object)

# %% [markdown]
# IMPUTING USING MEASURES OF CENTRAL TENDENCY

# %%
#calculating the statistics for purpose of imputing
df1.describe()
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count         122.000000            331.000000              297.000000
# mean            1.319672              1.972810                0.447811
# std             0.741524              2.961754                2.004590
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              1.000000                0.000000
# 75%             2.000000              3.000000                0.000000
# max             4.000000             19.000000               26.000000
#
#        Total.Minor.Injuries  Total.Uninjured
# count            293.000000       304.000000
# mean               0.409556        11.302632
# std                1.549252        39.498262
# min                0.000000         0.000000
# 25%                0.000000         0.000000
# 50%                0.000000         0.000000
# ...

# %%
## Checking Missing 

df1.isna().sum()
# Out:
# Event.Id                    0
# Investigation.Type          0
# Accident.Number             0
# Event.Date                  0
# Location                    0
# Country                     0
# Latitude                  262
# Longitude                 262
# Airport.Code              319
# Airport.Name              320
# Injury.Severity            49
# Aircraft.damage            57
# Aircraft.Category         113
# Registration.Number        64
# Make                        0
# Model                       1
# Amateur.Built               0
# Number.of.Engines         236
# Engine.Type               225
# FAR.Description           132
# Schedule                  264
# Purpose.of.flight         201
# Air.carrier               264
# Total.Fatal.Injuries       27
# Total.Serious.Injuries     61
# Total.Minor.Injuries       65
# Total.Uninjured            54
# Weather.Condition         196
# Broad.phase.of.flight     356
# Report.Status             215
# Publication.Date           80
# ...

# %%
#dropping the columns event.id
df1 = df1.drop(columns='Event.Id')

# %%
#The null values in them is greater than 90 percent
df1 = df1.drop(columns='Broad.phase.of.flight')

# %%
# Only select numeric columns checking data uniformity 
numeric_columns = df.select_dtypes(include=['number']).columns[:]

# %%
#replacing numeric null values by checking the uniformity of the data
df1.hist(bins=15, figsize=(20,13));

# %%
#checking how median differ from mean for number of engines not so much different from the mean
median_engines = df1['Number.of.Engines'].median()
median_engines
# Out:
# 1.0

# %%
# check for unique values in each column

for column in df1:
  unique_values = df1[column].unique()
  print(f"Unique values in column '{column}','\n': {unique_values}",'\n')
# Out:
# Unique values in column 'Investigation.Type','
# ': ['Incident' 'Accident']
#
# Unique values in column 'Accident.Number','
# ': ['FTW85IA168' 'FTW87RA066' 'FTW87WA070' 'LAX87WA216' 'DCA88RA002'
#  'LAX88FA045' 'LAX88WA068' 'LAX88WA067' 'LAX88WA105' 'LAX88WA165'
#  'LAX88WA185' 'LAX88WA237' 'LAX88WA323' 'FTW89RA034' 'LAX89WA260'
#  'LAX89WA293' 'LAX89WA326' 'LAX92WA284' 'FTW92WA236' 'FTW92WA231'
#  'FTW93WA018' 'MIA93WA010' 'FTW93WA054' 'LAX93WA090' 'LAX93WA145'
#  'FTW93WA107A' 'FTW93WA107B' 'LAX93WA184' 'FTW93WA270' 'FTW93WA259'
#  'LAX94WA053' 'FTW94WA073' 'LAX94WA341' 'FTW95WA037' 'LAX95WA056'
#  'FTW95WA081' 'LAX95WA185' 'FTW95RA287' 'LAX96WA014' 'LAX96WA038'
#  'FTW96RA037' 'FTW96WA342' 'LAX96WA057' 'LAX96WA063' 'LAX96RA116'
#  'FTW96WA220' 'LAX97WA094' 'FTW97RA101' 'LAX97WA109' 'FTW97WA133'
#  'DCA97WA035' 'LAX97WA194' 'FTW97RA194' 'FTW97RA314' 'LAX98WA032'
#  'FTW98RA119' 'DCA98WA026' 'DCA98WA027' 'FTW98RA401' 'FTW99WA109A'
# ...

# %%
#checking the columns
df1.columns
# Out:
# Index(['Investigation.Type', 'Accident.Number', 'Event.Date', 'Location',
#        'Country', 'Latitude', 'Longitude', 'Airport.Code', 'Airport.Name',
#        'Injury.Severity', 'Aircraft.damage', 'Aircraft.Category',
#        'Registration.Number', 'Make', 'Model', 'Amateur.Built',
#        'Number.of.Engines', 'Engine.Type', 'FAR.Description', 'Schedule',
#        'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Report.Status', 'Publication.Date'],
#       dtype='object')

# %%
#To change column names to lower case,
df1.columns = df1.columns.str.lower()

# %%
df1.columns
# Out:
# Index(['investigation.type', 'accident.number', 'event.date', 'location',
#        'country', 'latitude', 'longitude', 'airport.code', 'airport.name',
#        'injury.severity', 'aircraft.damage', 'aircraft.category',
#        'registration.number', 'make', 'model', 'amateur.built',
#        'number.of.engines', 'engine.type', 'far.description', 'schedule',
#        'purpose.of.flight', 'air.carrier', 'total.fatal.injuries',
#        'total.serious.injuries', 'total.minor.injuries', 'total.uninjured',
#        'weather.condition', 'report.status', 'publication.date'],
#       dtype='object')

# %%
#filling null values  witnh median in number of engines
df1['number.of.engines'].fillna(median_engines, inplace=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_17188\3615458373.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['number.of.engines'].fillna(median_engines, inplace=True)

# %%
df1['number.of.engines']
# Out:
# 11207    3.0
# 16837    4.0
# 16866    1.0
# 17578    2.0
# 19110    0.0
#         ...
# 87880    1.0
# 87909    2.0
# 88104    1.0
# 88136    2.0
# 88603    1.0
# Name: number.of.engines, Length: 358, dtype: float64

# %%
mean_total_serious_injuries = df1['total.serious.injuries'].mean()
mean_total_serious_injuries
# Out:
# 0.4478114478114478

# %%
df1['total.serious.injuries'].fillna(mean_total_serious_injuries, inplace=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_17188\2471531496.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['total.serious.injuries'].fillna(mean_total_serious_injuries, inplace=True)

# %%
df1['total.serious.injuries']
# Out:
# 11207    0.000000
# 16837    0.447811
# 16866    0.000000
# 17578    0.000000
# 19110    0.447811
#            ...
# 87880    0.000000
# 87909    0.000000
# 88104    0.000000
# 88136    0.000000
# 88603    0.000000
# Name: total.serious.injuries, Length: 358, dtype: float64

# %%
#imputing using the mean
df1['total.serious.injuries'].replace(0,mean_total_serious_injuries,inplace=True)

# %%
df1['total.serious.injuries']
# Out:
# 11207    0.447811
# 16837    0.447811
# 16866    0.447811
# 17578    0.447811
# 19110    0.447811
#            ...
# 87880    0.447811
# 87909    0.447811
# 88104    0.447811
# 88136    0.447811
# 88603    0.447811
# Name: total.serious.injuries, Length: 358, dtype: float64

# %%
#imputing total uninjured using the mean
total_uninjured_mean=df1['total.uninjured'].mean()
total_uninjured_mean
# Out:
# 11.302631578947368

# %%
df1['total.uninjured'].fillna(total_uninjured_mean,inplace=True)
df1['total.uninjured']
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_17188\1179951135.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['total.uninjured'].fillna(total_uninjured_mean,inplace=True)
# 11207    152.000000
# 16837    131.000000
# 16866      0.000000
# 17578      0.000000
# 19110     11.302632
#             ...
# 87880      0.000000
# 87909      0.000000
# 88104      5.000000
# 88136      0.000000
# 88603      0.000000
# Name: total.uninjured, Length: 358, dtype: float64

# %%
df1.columns
# Out:
# Index(['investigation.type', 'accident.number', 'event.date', 'location',
#        'country', 'latitude', 'longitude', 'airport.code', 'airport.name',
#        'injury.severity', 'aircraft.damage', 'aircraft.category',
#        'registration.number', 'make', 'model', 'amateur.built',
#        'number.of.engines', 'engine.type', 'far.description', 'schedule',
#        'purpose.of.flight', 'air.carrier', 'total.fatal.injuries',
#        'total.serious.injuries', 'total.minor.injuries', 'total.uninjured',
#        'weather.condition', 'report.status', 'publication.date'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 358 entries, 11207 to 88603
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   investigation.type      358 non-null    object
#  1   accident.number         358 non-null    object
#  2   event.date              358 non-null    object
#  3   location                358 non-null    object
#  4   country                 358 non-null    object
#  5   latitude                96 non-null     object
#  6   longitude               96 non-null     object
#  7   airport.code            39 non-null     object
#  8   airport.name            38 non-null     object
#  9   injury.severity         309 non-null    object
#  10  aircraft.damage         301 non-null    object
#  11  aircraft.category       245 non-null    object
#  12  registration.number     294 non-null    object
#  13  make                    358 non-null    object
# ...

# %%
categorical_columns = df1.select_dtypes(include=['object']).columns[:]
categorical_columns
# Out:
# Index(['investigation.type', 'accident.number', 'event.date', 'location',
#        'country', 'latitude', 'longitude', 'airport.code', 'airport.name',
#        'injury.severity', 'aircraft.damage', 'aircraft.category',
#        'registration.number', 'make', 'model', 'amateur.built', 'engine.type',
#        'far.description', 'schedule', 'purpose.of.flight', 'air.carrier',
#        'weather.condition', 'report.status', 'publication.date'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
# Specify the categorical columns you want to plot
cat_columns = [  'aircraft.damage', 'aircraft.category','make', 'purpose.of.flight']

# Define grid layout for the subplots
rows, cols = 2, 2  # Adjusted grid layout since you have 2 columns to plot
fig, axes = plt.subplots(rows, cols, figsize=(13, 5))

# Flatten the axes array to make indexing easier
axes = axes.flatten()

# Loop through each column and plot using Seaborn's countplot
for i, column in enumerate(cat_columns):
    # Use Seaborn's countplot for categorical data
    sns.countplot(data=df1, x=column, ax=axes[i], palette='Set2', hue=column)
    
    # Set plot title and labels
    axes[i].set_title(f'Frequency Distribution of {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Frequency')
    axes[i].tick_params(axis='x', rotation=0)  # Rotate x labels for readability

    
# Hide empty subplots 
for j in range (i + 1, rows * cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %%
#data visualisation1 univariate
df1.hist("number.of.engines" ,bins=15, figsize=(20,13));
plt.title("number.of.engines",color="teal")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# CHECKING FOR DUPLICATES

# %%
#check duplicates # use duplicatede()
df1.duplicated().sum()
# Out:
# 0

# %%
ws, cols = 5, 4
fig, axes = plt.subplots(rows, cols, figsize=(20, 10))


# Flatten 
axes = axes.flatten()

for i, column in enumerate(numeric_columns):
    sns.boxplot(x=df[column], ax = axes[i])
    axes[i].set_title(f"Box plot for {column}")
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Value')
    
# Hide empty subplots 
for j in range(i + 1, rows * cols):
    axes[j].axis('off')
    
plt.tight_layout()
plt.show()

# %%
#Remove the outlier using the maximum quantile
max_total_serious_injuries = df1["total.serious.injuries"].quantile(0.995)
max_total_serious_injuries
# Out:
# 10.8599999999999

# %%
#check the outliers #df1[df1["total.serious.injuries"] > max_total_serious_injuries]
df1[df1["total.serious.injuries"]>max_total_serious_injuries]
# Out:
#       investigation.type accident.number  event.date           location  \
# 73992           Accident      DCA13WA134  2013-07-31  Batopilas, Mexico
# 82033           Accident      DCA18RA253  2018-07-31    Durango, Mexico
#
#       country latitude longitude airport.code                    airport.name  \
# 73992  Mexico  027112N  1073216W          NaN                             NaN
# 82033  Mexico      NaN       NaN         MMDO  General Guadalupe Victoria Int
#
#       injury.severity  ... schedule purpose.of.flight          air.carrier  \
# 73992       Non-Fatal  ...     SCHD               NaN  AIRTRAN AIRWAYS INC
# 82033       Non-Fatal  ...     SCHD               NaN           AeroMexico
#
#       total.fatal.injuries total.serious.injuries total.minor.injuries  \
# 73992                  0.0                   14.0                  1.0
# 82033                  0.0                   26.0                 16.0
#
# ...

# %%
#confirm removal of outlier
df2 = df1[df1["total.serious.injuries"]<max_total_serious_injuries ]

# %%
sns.boxplot(df2["total.serious.injuries"])
# Out:
# <Axes: ylabel='total.serious.injuries'>

# %%
df2.describe()
# Out:
#        number.of.engines  total.fatal.injuries  total.serious.injuries  \
# count         356.000000            329.000000              356.000000
# mean            1.109551              1.984802                0.663763
# std             0.458803              2.966749                0.894938
# min             0.000000              0.000000                0.447811
# 25%             1.000000              0.000000                0.447811
# 50%             1.000000              1.000000                0.447811
# 75%             1.000000              3.000000                0.447811
# max             4.000000             19.000000               10.000000
#
#        total.minor.injuries  total.uninjured
# count            291.000000       356.000000
# mean               0.353952        10.832422
# std                1.254706        35.846895
# min                0.000000         0.000000
# 25%                0.000000         0.000000
# 50%                0.000000         0.000000
# ...

# %%
#Remove the outlier using the maximum quantile
max_total_minor_injuries = df1["total.minor.injuries"].quantile(0.995)
max_total_minor_injuries
# Out:
# 11.080000000000041

# %%
#confirm removal of outlier
df2 = df1[df1["total.minor.injuries"]<max_total_minor_injuries ]

# %%
#Remove the outlier using the maximum quantile
max_total_fatal_injuries = df1["total.fatal.injuries"].quantile(0.995)
max_total_fatal_injuries
# Out:
# 18.350000000000023

# %%
#confirm removal of outlier
df2 = df1[df1["total.fatal.injuries"]<max_total_fatal_injuries ]

# %%
ws, cols = 5, 4
fig, axes = plt.subplots(rows, cols, figsize=(20, 10))


# Flatten 
axes = axes.flatten()

for i, column in enumerate(numeric_columns):
    sns.boxplot(x=df[column], ax = axes[i])
    axes[i].set_title(f"Box plot for {column}")
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Value')
    
# Hide empty subplots 
for j in range(i + 1, rows * cols):
    axes[j].axis('off')
    
plt.tight_layout()
plt.show()

# %%
#SAVING THE CLEAN DATA AS mexico clean csv file

# %%
#save the new dataframe in csv format
#df2.to_csv('clean_data.csv', index=False)
df2.to_csv("Mexico_clean.csv", index=False)

# %%
#load the clean Dataset and create a adataframe
data = pd.read_csv("Mexico_clean.csv")
data.head()
# Out:
#   investigation.type accident.number  event.date                 location  \
# 0           Incident      FTW85IA168  1985-03-29      MEXICO CITY, Mexico
# 1           Accident      FTW87RA066  1987-02-14          DURANGO, Mexico
# 2           Accident      FTW87WA070  1987-02-20  LA UNION MORALE, Mexico
# 3           Accident      LAX87WA216  1987-05-23         MEXICALI, MEXICO
# 4           Accident      LAX88FA045  1987-11-15         MEXICALI, Mexico
#
#   country latitude longitude airport.code airport.name injury.severity  ...  \
# 0  Mexico      NaN       NaN          DFW          DFW        Incident  ...
# 1  Mexico      NaN       NaN          NaN          NaN        Fatal(1)  ...
# 2  Mexico      NaN       NaN          NaN          NaN        Fatal(3)  ...
# 3  Mexico      NaN       NaN          NaN          NaN       Non-Fatal  ...
# 4  Mexico      NaN       NaN          NaN          NaN        Fatal(2)  ...
#
# ...

# %% [markdown]
# DATA VISUALISATION

# %%
#data visualisation1 univariate
df2.hist("number.of.engines" ,bins=15, figsize=(20,13));
plt.title("number.of.engines",color="teal")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#plotting total fatal injuries vs the make
# Select the top 20 makes with the highest total fatal injuries
top_20_makes = df2.groupby('make')['total.fatal.injuries'].sum().reset_index()
top_20_makes = top_20_makes.sort_values(by='total.fatal.injuries', ascending=False).head(20)
top_20_makes['Category'] = ['High' if x > top_20_makes['total.fatal.injuries'].median() else 'Low' for x in top_20_makes['total.fatal.injuries']]

# Plot the bar graph for the top 20 makes with hue
plt.figure(figsize=(14, 8))
sns.barplot(
    data=top_20_makes, 
    x='make', 
    y='total.fatal.injuries', 
    hue='Category',  # Add hue for grouping
    palette='viridis', 
    errorbar=None  
)
plt.title("Top 20 Makes by Total Fatal Injuries", fontsize=16)
plt.xlabel("Vehicle Make", fontsize=12)
plt.ylabel("Total Fatal Injuries", fontsize=12)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.legend(title="Injury Category")  # Add legend
plt.tight_layout()
plt.show()

# %%
# Group data for plotting
# Grouping 'make' vs. 'uninjured'
make_versus_total_uninjured = df2.groupby('make')['total.uninjured'].sum().reset_index()
make_versus_total_uninjured = make_versus_total_uninjured.sort_values(by='total.uninjured', ascending=False).head(20)

# Grouping 'make' vs. 'aircraft.damage'
make_damage = df2.groupby('make')['aircraft.damage'].value_counts().unstack().fillna(0).reset_index()
make_damage = make_damage[make_damage['make'].isin(make_versus_total_uninjured['make'])]  # Ensure same top 20 makes

# Create subplots
fig, axs = plt.subplots(2, 1, figsize=(14, 14))

# Plotting 'make' vs. 'uninjured'
sns.barplot(
    data=make_versus_total_uninjured, 
    x='make', 
    y='total.uninjured', 
    palette='Blues_d', 
    ax=axs[0]
)
axs[0].set_title("Top 20 Makes by Number of Uninjured People", fontsize=16)
axs[0].set_xlabel("Aircraft Make", fontsize=12)
axs[0].set_ylabel("Number of Uninjured", fontsize=12)
axs[0].tick_params(axis='x', rotation=45)

# Plotting 'make' vs. 'aircraft.damage'
damage_types = [col for col in make_damage.columns if col != 'make']
make_damage_melted = make_damage.melt(id_vars='make', value_vars=damage_types, var_name='Damage Type', value_name='Count')

sns.barplot(
    data=make_damage_melted, 
    x='make', 
    y='Count', 
    hue='Damage Type',  # Keep 'hue' for grouping by damage type
    palette='Set2', 
    ax=axs[1]
)
axs[1].set_title("Aircraft Damage by Make", fontsize=16)
axs[1].set_xlabel("Aircraft Make", fontsize=12)
axs[1].set_ylabel("Count", fontsize=12)
axs[1].tick_params(axis='x', rotation=45)
axs[1].legend(title="Damage Type", loc='upper right')  # Legend showing damage types

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_17188\105530261.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
